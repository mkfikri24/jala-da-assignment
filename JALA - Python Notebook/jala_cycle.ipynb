# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data_cycle = pd.read_csv('/content/drive/MyDrive/jala_performance_cycle.csv')

# %%
data_cycle
# Out:
#      cycles_id  total_seed                      started_at  \
# 0        12865        2800  2023-04-07 00:00:00.000000 UTC
# 1        18133       69000  2021-09-03 00:00:00.000000 UTC
# 2        18536       84192  2022-08-19 00:00:00.000000 UTC
# 3        12864      382888  2022-03-09 00:00:00.000000 UTC
# 4        18923      574000  2022-02-05 00:00:00.000000 UTC
# ..         ...         ...                             ...
# 393      17187       75000  2023-02-19 00:00:00.000000 UTC
# 394      16711       74750  2022-04-11 00:00:00.000000 UTC
# 395      18755       74750  2022-04-11 00:00:00.000000 UTC
# 396      15772      365310  2022-11-16 00:00:00.000000 UTC
# 397      21089      365310  2022-11-16 00:00:00.000000 UTC
#
#                         finished_at     area  padat_tebar  cycle_day_count  \
# 0    2023-05-30 00:00:00.000000 UTC     7.07   396.039604               53
# 1    2021-11-09 00:00:00.000000 UTC   300.00   230.000000               67
# 2    2022-10-09 00:00:00.000000 UTC  1000.00    84.192000               51
# 3    2022-05-16 00:00:00.000000 UTC  1713.00   223.518973               68
# 4    2022-04-21 00:00:00.000000 UTC  3500.00   164.000000               75
# ..                              ...      ...          ...              ...
# 393  2023-04-12 00:00:00.000000 UTC   899.00    83.426029               52
# 394  2022-06-25 00:00:00.000000 UTC  1000.00    74.750000               75
# 395  2022-06-25 00:00:00.000000 UTC  1000.00    74.750000               75
# 396  2023-02-04 00:00:00.000000 UTC  2345.28   155.763917               80
# 397  2023-02-03 00:00:00.000000 UTC  2405.08   151.890997               79
#
#      count_feed  sum_feed_weight  count_fasting  ...  avg_hardness  \
# 0           187           21.564            8.0  ...           NaN
# 1            66         1163.250            NaN  ...           NaN
# 2           206          779.700            6.0  ...   2076.000000
# 3            67         4443.900            1.0  ...           NaN
# 4           315         7663.000            NaN  ...           NaN
# ..          ...              ...            ...  ...           ...
# 393         168          199.200           19.0  ...           NaN
# 394         406         1336.500            1.0  ...   6700.000000
# 395         410         1316.500            1.0  ...   6500.000000
# 396         241         5374.000            9.0  ...   4481.818182
# 397         241         5428.000            8.0  ...   4554.545455
#
#      avg_calcium  avg_magnesium  avg_carbonate  avg_bicarbonate     avg_tom  \
# 0            NaN            NaN            NaN              NaN         NaN
# 1            NaN            NaN            NaN              NaN         NaN
# 2     245.833333     710.333333            NaN      9910.500000   97.773333
# 3            NaN            NaN            NaN              NaN         NaN
# 4            NaN            NaN            NaN              NaN         NaN
# ..           ...            ...            ...              ...         ...
# 393          NaN            NaN            NaN              NaN         NaN
# 394  2000.000000    4700.000000            NaN        68.000000         NaN
# 395  1900.000000    4600.000000            NaN        92.000000         NaN
# 396   429.090909     984.818182       3.636364       104.000000  100.727273
# 397   407.272727    1007.818182       4.363636       105.818182  103.000000
#
#      avg_total_plankton       ADG         SR       FCR
# 0                   NaN  0.169867  24.142857  4.146923
# 1                   NaN  0.303303  47.157101  2.860005
# 2            220000.000  0.371429  47.013814  1.824073
# 3                21.125  0.386667  41.852121  2.010542
# 4                   NaN  0.432527  28.660714  2.329002
# ..                  ...       ...        ...       ...
# 393                 NaN  0.205000  24.000000  2.213333
# 394          230000.000  0.263200  71.083746  2.129371
# 395           30000.000  0.212600  67.810569  2.300367
# 396         1657250.000  0.305804  46.415399  2.070555
# 397         1877500.000  0.272173  50.806664  2.034018
#
# [398 rows x 36 columns]

# %%
data_cycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cycles_id                398 non-null    int64
#  1   total_seed               398 non-null    int64
#  2   started_at               398 non-null    object
#  3   finished_at              398 non-null    object
#  4   area                     398 non-null    float64
#  5   padat_tebar              398 non-null    float64
#  6   cycle_day_count          398 non-null    int64
#  7   count_feed               398 non-null    int64
#  8   sum_feed_weight          398 non-null    float64
#  9   count_fasting            271 non-null    float64
#  10  sum_size_per_kg          398 non-null    float64
#  11  sum_weight_biomassa      398 non-null    float64
#  12  sum_biomassa             398 non-null    float64
#  13  avg_morning_temperature  379 non-null    float64
#  14  avg_evening_temperature  356 non-null    float64
#  15  avg_morning_do           313 non-null    float64
#  16  avg_evening_do           292 non-null    float64
#  17  avg_morning_salinity     356 non-null    float64
#  18  avg_evening_salinity     295 non-null    float64
#  19  avg_morning_pH           392 non-null    float64
#  20  avg_evening_pH           331 non-null    float64
#  21  avg_transparency         297 non-null    float64
#  22  avg_ammonia              168 non-null    float64
#  23  avg_nitrate              79 non-null     float64
#  24  avg_nitrite              284 non-null    float64
#  25  avg_alkalinity           293 non-null    float64
#  26  avg_hardness             210 non-null    float64
#  27  avg_calcium              227 non-null    float64
#  28  avg_magnesium            227 non-null    float64
#  29  avg_carbonate            197 non-null    float64
#  30  avg_bicarbonate          213 non-null    float64
#  31  avg_tom                  207 non-null    float64
#  32  avg_total_plankton       245 non-null    float64
#  33  ADG                      398 non-null    float64
#  34  SR                       398 non-null    float64
#  35  FCR                      398 non-null    float64
# dtypes: float64(30), int64(4), object(2)
# memory usage: 112.1+ KB

# %%
def classify_budidaya(padat_tebar):
    if padat_tebar <= 5:
        return 'Sederhana'
    elif 5 < padat_tebar <= 15:
        return 'Semi Intensif'
    elif 15 < padat_tebar <= 50:
        return 'Intensif'
    else:
        return 'Super Intensif'

data_cycle['jenis_budidaya'] = data_cycle['padat_tebar'].apply(classify_budidaya)

print(data_cycle[['padat_tebar', 'jenis_budidaya']])
# Out:
#      padat_tebar  jenis_budidaya
# 0     396.039604  Super Intensif
# 1     230.000000  Super Intensif
# 2      84.192000  Super Intensif
# 3     223.518973  Super Intensif
# 4     164.000000  Super Intensif
# ..           ...             ...
# 393    83.426029  Super Intensif
# 394    74.750000  Super Intensif
# 395    74.750000  Super Intensif
# 396   155.763917  Super Intensif
# 397   151.890997  Super Intensif
#
# [398 rows x 2 columns]

# %%
jenis_budidaya_counts = data_cycle['jenis_budidaya'].value_counts()

print(jenis_budidaya_counts)
# Out:
# jenis_budidaya
# Super Intensif    374
# Intensif           22
# Semi Intensif       2
# Name: count, dtype: int64

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    optimal_interval = {'lower_bound': lower_bound, 'upper_bound': upper_bound}
    return outliers, optimal_interval

outliers_adg_cycle, optimal_adg_interval = detect_outliers_iqr(data_cycle, 'ADG')
outliers_sr_cycle, optimal_sr_interval = detect_outliers_iqr(data_cycle, 'SR')
outliers_fcr_cycle, optimal_fcr_interval = detect_outliers_iqr(data_cycle, 'FCR')

outliers_counts_cycle = {
    'ADG': outliers_adg_cycle.shape[0],
    'SR': outliers_sr_cycle.shape[0],
    'FCR': outliers_fcr_cycle.shape[0]
}

print(outliers_counts_cycle)
print("----------------------------------------------------------------------------------")
print(outliers_adg_cycle[['ADG']].describe())
print(outliers_sr_cycle[['SR']].describe())
print(outliers_fcr_cycle[['FCR']].describe())
print("----------------------------------------------------------------------------------")
print("Optimal ADG :",optimal_adg_interval)
print("Optimal SR  :",optimal_sr_interval)
print("Optimal FCR :",optimal_fcr_interval)
# Out:
# {'ADG': 8, 'SR': 7, 'FCR': 36}
# ----------------------------------------------------------------------------------
#             ADG
# count  8.000000
# mean   0.635578
# std    0.340602
# min   -0.072768
# 25%    0.528417
# 50%    0.679929
# 75%    0.805149
# max    1.071429
#                SR
# count    7.000000
# mean   137.211229
# std     52.303978
# min    107.848000
# 25%    112.083762
# 50%    118.533333
# 75%    128.092014
# max    253.745714
#              FCR
# count  36.000000
# mean   12.196115
# std     9.797158
# min     5.585251
# 25%     6.570148
# 50%     8.519999
# 75%    14.115327
# max    53.412500
# ----------------------------------------------------------------------------------
# Optimal ADG : {'lower_bound': 0.007529761904761845, 'upper_bound': 0.5015456349206349}
# Optimal SR  : {'lower_bound': -26.9101473443639, 'upper_bound': 107.4079203517176}
# Optimal FCR : {'lower_bound': -0.5938228820031408, 'upper_bound': 5.582090687136809}

# %%
print("\nADG Outliers Values:")
print(outliers_adg_cycle[['cycles_id','ADG']].sort_values(by='ADG'))

print("\nSR Outliers Values:")
print(outliers_sr_cycle[['cycles_id','SR']].sort_values(by='SR'))

print("\nFCR Outliers Values:")
print(outliers_fcr_cycle[['cycles_id','FCR']].sort_values(by='FCR'))
# Out:
# ADG Outliers Values:
#      cycles_id       ADG
# 107      14824 -0.072768
# 328      16050  0.516667
# 318      18591  0.532333
# 234      15516  0.667857
# 378      16708  0.692001
# 353      19370  0.771746
# 109      16064  0.905357
# 169      22268  1.071429
#
# SR Outliers Values:
#      cycles_id          SR
# 215      19238  107.848000
# 240      16575  108.693750
# 128      17563  115.473774
# 379       9098  118.533333
# 133      19653  118.850695
# 353      19370  137.333333
# 165      15835  253.745714
#
# FCR Outliers Values:
#      cycles_id        FCR
# 377      15304   5.585251
# 290      19687   5.587838
# 279      18395   5.606667
# 237      18360   5.838436
# 364      15305   6.067010
# 285      15758   6.124514
# 139      20401   6.150149
# 63       20216   6.376563
# 153      15499   6.495381
# 110      17857   6.595070
# 325      20429   6.703704
# 151      20024   6.787015
# 32       23362   6.795299
# 48       21347   6.979554
# 306      19068   7.622885
# 391      15773   7.623278
# 380      19310   8.112500
# 131      21413   8.467998
# 226      14693   8.572000
# 11       18673   8.655535
# 277      18958   8.664399
# 5        19640  10.581451
# 293      21098  10.920455
# 41       18446  11.663782
# 323      17739  13.147491
# 322      17717  13.527758
# 189      17832  14.085714
# 378      16708  14.204167
# 74       11081  14.932576
# 94       17633  15.532405
# 321      19294  16.250000
# 381       9097  18.020578
# 382      20664  21.555960
# 107      14824  29.364407
# 268      17404  36.449835
# 109      16064  53.412500

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

numeric_columns = data_cycle.select_dtypes(include=[np.number]).columns
numeric_data = data_cycle[numeric_columns]

correlation_matrix = numeric_data.corr()
plt.figure(figsize=(25, 13), dpi=100)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
sns.boxplot(data=data_cycle, y='ADG')
plt.title('ADG of Cycle')

plt.subplot(1, 3, 2)
sns.boxplot(data=data_cycle, y='SR')
plt.title('SR of Cycle')

plt.subplot(1, 3, 3)
sns.boxplot(data=data_cycle, y='FCR')
plt.title('FCR of Cycle')

plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# Memisahkan fitur dan target
X = data_cycle.drop(columns=['started_at', 'finished_at', 'ADG', 'SR', 'FCR', 'jenis_budidaya'])
X = pd.get_dummies(X, drop_first=True)  # Mengubah variabel kategorikal menjadi numerik

# Model untuk masing-masing target
y_adg = data_cycle['ADG']
y_sr = data_cycle['SR']
y_fcr = data_cycle['FCR']

model_adg = RandomForestRegressor(random_state=42)
model_sr = RandomForestRegressor(random_state=42)
model_fcr = RandomForestRegressor(random_state=42)

X = X.fillna(X.median())

model_adg.fit(X, y_adg)
model_sr.fit(X, y_sr)
model_fcr.fit(X, y_fcr)

# Mendapatkan feature importances
importances_adg = model_adg.feature_importances_
importances_sr = model_sr.feature_importances_
importances_fcr = model_fcr.feature_importances_

# Plot feature importances
features = X.columns
indices_adg = np.argsort(importances_adg)
indices_sr = np.argsort(importances_sr)
indices_fcr = np.argsort(importances_fcr)

plt.figure(figsize=(20, 10))

plt.subplot(1, 3, 1)
plt.title('Feature Importances for ADG')
plt.barh(range(len(indices_adg)), importances_adg[indices_adg], align='center')
plt.yticks(range(len(indices_adg)), [features[i] for i in indices_adg])

plt.subplot(1, 3, 2)
plt.title('Feature Importances for SR')
plt.barh(range(len(indices_sr)), importances_sr[indices_sr], align='center')
plt.yticks(range(len(indices_sr)), [features[i] for i in indices_sr])

plt.subplot(1, 3, 3)
plt.title('Feature Importances for FCR')
plt.barh(range(len(indices_fcr)), importances_fcr[indices_fcr], align='center')
plt.yticks(range(len(indices_fcr)), [features[i] for i in indices_fcr])

plt.tight_layout()
plt.show()

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers.index

# Mendeteksi outliers pada masing-masing kolom
outliers_adg = detect_outliers_iqr(data_cycle, 'ADG')
outliers_sr = detect_outliers_iqr(data_cycle, 'SR')
outliers_fcr = detect_outliers_iqr(data_cycle, 'FCR')

# Menggabungkan semua indeks outliers
all_outliers = set(outliers_adg).union(set(outliers_sr)).union(set(outliers_fcr))

# Mengonversi set all_outliers menjadi list
all_outliers_list = list(all_outliers)

# Membuat dataset yang memiliki outliers
df_with_outliers = pd.DataFrame(data_cycle.loc[all_outliers_list])

# Membuat dataset yang tidak memiliki outliers
df_without_outliers = pd.DataFrame(data_cycle.drop(index=all_outliers_list))

# %%
from scipy.stats import ttest_ind

# List semua kolom numerik
numerical_cols_with_outliers = df_with_outliers.select_dtypes(include=['number']).columns.tolist()
numerical_cols_without_outliers = df_without_outliers.select_dtypes(include=['number']).columns.tolist()

# Mengisi nilai-nilai yang hilang dengan median untuk setiap kolom numerik
df_with_outliers[numerical_cols_with_outliers] = df_with_outliers[numerical_cols_with_outliers].fillna(df_with_outliers[numerical_cols_with_outliers].median())
df_without_outliers[numerical_cols_without_outliers] = df_without_outliers[numerical_cols_without_outliers].fillna(df_without_outliers[numerical_cols_without_outliers].median())

# Lakukan uji t-test untuk setiap kolom numerik di kedua dataset
for col in numerical_cols_with_outliers:
    t_stat, p_val = ttest_ind(df_with_outliers[col], df_without_outliers[col])
    print(f'T-test between {col} with outliers and {col} without outliers:')
    print(f'T-statistic: {t_stat}, P-value: {p_val}')
    if p_val < 0.05:
        print(f'P-value is less than 0.05, there is significant difference between the columns.\n')
    else:
        print(f'P-value is greater than or equal to 0.05, there is no significant difference between the columns.\n')
# Out:
# T-test between cycles_id with outliers and cycles_id without outliers:
# T-statistic: 0.01787336444985093, P-value: 0.9857488793771729
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between total_seed with outliers and total_seed without outliers:
# T-statistic: -1.8594989159053474, P-value: 0.06369786505980814
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between area with outliers and area without outliers:
# T-statistic: -2.027539366731618, P-value: 0.04327650202808647
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between padat_tebar with outliers and padat_tebar without outliers:
# T-statistic: 4.464471704167663, P-value: 1.0480975487958222e-05
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between cycle_day_count with outliers and cycle_day_count without outliers:
# T-statistic: -1.5407114699374862, P-value: 0.12418569759919561
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between count_feed with outliers and count_feed without outliers:
# T-statistic: -1.938062121914603, P-value: 0.053326111094182754
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between sum_feed_weight with outliers and sum_feed_weight without outliers:
# T-statistic: -3.653396217937042, P-value: 0.000293601769934314
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between count_fasting with outliers and count_fasting without outliers:
# T-statistic: 0.8501669710437674, P-value: 0.3957459822989684
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between sum_size_per_kg with outliers and sum_size_per_kg without outliers:
# T-statistic: -0.9549917193847265, P-value: 0.3401644818937277
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between sum_weight_biomassa with outliers and sum_weight_biomassa without outliers:
# T-statistic: -4.4588913561606525, P-value: 1.074410051319721e-05
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between sum_biomassa with outliers and sum_biomassa without outliers:
# T-statistic: -3.8581682762140885, P-value: 0.00013332915733803015
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_morning_temperature with outliers and avg_morning_temperature without outliers:
# T-statistic: -0.4087365043585547, P-value: 0.6829539884461842
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_evening_temperature with outliers and avg_evening_temperature without outliers:
# T-statistic: -0.3967323431434064, P-value: 0.6917785595747896
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_morning_do with outliers and avg_morning_do without outliers:
# T-statistic: -0.32330694489227, P-value: 0.7466334540128785
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_evening_do with outliers and avg_evening_do without outliers:
# T-statistic: 2.322293303258274, P-value: 0.020723444167835572
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_morning_salinity with outliers and avg_morning_salinity without outliers:
# T-statistic: -2.287093033322691, P-value: 0.022717231652343524
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_evening_salinity with outliers and avg_evening_salinity without outliers:
# T-statistic: -2.788717459384719, P-value: 0.0055470328360405574
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_morning_pH with outliers and avg_morning_pH without outliers:
# T-statistic: -0.4412718367328556, P-value: 0.659257043574473
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_evening_pH with outliers and avg_evening_pH without outliers:
# T-statistic: -0.2685038710540493, P-value: 0.7884513152080352
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_transparency with outliers and avg_transparency without outliers:
# T-statistic: -2.3415922615099842, P-value: 0.019696694938480926
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_ammonia with outliers and avg_ammonia without outliers:
# T-statistic: 2.2385644612932163, P-value: 0.025739227781695323
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_nitrate with outliers and avg_nitrate without outliers:
# T-statistic: -0.4782495025181126, P-value: 0.6327365455889095
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_nitrite with outliers and avg_nitrite without outliers:
# T-statistic: 1.550055801565769, P-value: 0.12192691282108378
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_alkalinity with outliers and avg_alkalinity without outliers:
# T-statistic: -0.2786890041964345, P-value: 0.7806289733677715
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_hardness with outliers and avg_hardness without outliers:
# T-statistic: -1.2545816301450645, P-value: 0.21037063922678104
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_calcium with outliers and avg_calcium without outliers:
# T-statistic: 2.3129542835210533, P-value: 0.021236905355276087
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_magnesium with outliers and avg_magnesium without outliers:
# T-statistic: 1.4113343600285269, P-value: 0.15893122622715006
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_carbonate with outliers and avg_carbonate without outliers:
# T-statistic: -0.8619503648052622, P-value: 0.38923647995759225
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_bicarbonate with outliers and avg_bicarbonate without outliers:
# T-statistic: -0.32590091036427454, P-value: 0.7446714724001968
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between avg_tom with outliers and avg_tom without outliers:
# T-statistic: -9.718724222298748, P-value: 3.641701956386388e-20
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between avg_total_plankton with outliers and avg_total_plankton without outliers:
# T-statistic: 0.6856029022580107, P-value: 0.4933647081443725
# P-value is greater than or equal to 0.05, there is no significant difference between the columns.
#
# T-test between ADG with outliers and ADG without outliers:
# T-statistic: 2.3728498469439545, P-value: 0.018128194681988816
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between SR with outliers and SR without outliers:
# T-statistic: -3.2931368841616027, P-value: 0.001079819513219416
# P-value is less than 0.05, there is significant difference between the columns.
#
# T-test between FCR with outliers and FCR without outliers:
# T-statistic: 13.499865569183633, P-value: 1.9792250437059606e-34
# P-value is less than 0.05, there is significant difference between the columns.

# %%
grouped_data_outliers = df_with_outliers.groupby('jenis_budidaya')
grouped_data_without_outliers = df_without_outliers.groupby('jenis_budidaya')

sederhana_data_outliers = grouped_data_outliers.get_group('Sederhana') if 'Sederhana' in grouped_data_outliers.groups else pd.DataFrame()
semi_intensif_data_outliers = grouped_data_outliers.get_group('Semi Intensif') if 'Semi Intensif' in grouped_data_outliers.groups else pd.DataFrame()
intensif_data_outliers = grouped_data_outliers.get_group('Intensif') if 'Intensif' in grouped_data_outliers.groups else pd.DataFrame()
super_intensif_data_outliers = grouped_data_outliers.get_group('Super Intensif') if 'Super Intensif' in grouped_data_outliers.groups else pd.DataFrame()

sederhana_data_without_outliers = grouped_data_without_outliers.get_group('Sederhana') if 'Sederhana' in grouped_data_without_outliers.groups else pd.DataFrame()
semi_intensif_data_without_outliers = grouped_data_without_outliers.get_group('Semi Intensif') if 'Semi Intensif' in grouped_data_without_outliers.groups else pd.DataFrame()
intensif_data_without_outliers = grouped_data_without_outliers.get_group('Intensif') if 'Intensif' in grouped_data_without_outliers.groups else pd.DataFrame()
super_intensif_data_without_outliers = grouped_data_without_outliers.get_group('Super Intensif') if 'Super Intensif' in grouped_data_without_outliers.groups else pd.DataFrame()

# %%
# Daftar kolom yang ingin dibandingkan
selected_columns = ['area', 'padat_tebar', 'sum_feed_weight', 'sum_weight_biomassa', 'sum_biomassa', 'avg_evening_do',
                    'avg_morning_salinity', 'avg_evening_salinity', 'avg_transparency', 'avg_ammonia', 'avg_calcium', 'avg_tom']

# Fungsi untuk menghitung interval nilai dan nilai yang paling stabil (modus) pada setiap kolom dalam dataframe
def get_non_empty_stats(df, columns):
    stats = {}
    if not df.empty:
        for column in columns:
            min_val = df[column].min()
            max_val = df[column].max()
            mode_val = df[column].mode()[0] if not df[column].mode().empty else None
            stats[column] = {
                'min': min_val,
                'max': max_val,
                'mode': mode_val
            }
    return stats

# Mendapatkan statistik untuk kedua dataset hanya pada kolom yang dipilih
stats_sederhana_data_outliers = get_non_empty_stats(sederhana_data_outliers, selected_columns)
stats_semi_intensif_data_outliers = get_non_empty_stats(semi_intensif_data_outliers, selected_columns)
stats_intensif_data_outliers = get_non_empty_stats(intensif_data_outliers, selected_columns)
stats_super_intensif_data_outliers = get_non_empty_stats(super_intensif_data_outliers, selected_columns)

stats_sederhana_data_without_outliers = get_non_empty_stats(sederhana_data_without_outliers, selected_columns)
stats_semi_intensif_data_without_outliers = get_non_empty_stats(semi_intensif_data_without_outliers, selected_columns)
stats_intensif_data_without_outliers = get_non_empty_stats(intensif_data_without_outliers, selected_columns)
stats_super_intensif_data_without_outliers = get_non_empty_stats(super_intensif_data_without_outliers, selected_columns)

# %%
datasets = {
    'sederhana_data_outliers': sederhana_data_outliers,
    'semi_intensif_data_outliers': semi_intensif_data_outliers,
    'intensif_data_outliers': intensif_data_outliers,
    'super_intensif_data_outliers': super_intensif_data_outliers,
    'sederhana_data_without_outliers': sederhana_data_without_outliers,
    'semi_intensif_data_without_outliers': semi_intensif_data_without_outliers,
    'intensif_data_without_outliers': intensif_data_without_outliers,
    'super_intensif_data_without_outliers': super_intensif_data_without_outliers
}

for name, df in datasets.items():
    if df.empty:
        print(f"Kosong: {name}")
    else:
        print(f"Tidak Kosong: {name}")
# Out:
# Kosong: sederhana_data_outliers
# Kosong: semi_intensif_data_outliers
# Tidak Kosong: intensif_data_outliers
# Tidak Kosong: super_intensif_data_outliers
# Kosong: sederhana_data_without_outliers
# Tidak Kosong: semi_intensif_data_without_outliers
# Tidak Kosong: intensif_data_without_outliers
# Tidak Kosong: super_intensif_data_without_outliers

# %%
# Membuat dataframe perbandingan interval dan nilai yang paling stabil
comparison = pd.DataFrame({
    'semi_intensif_data_without_outliers_min': {col: stats_semi_intensif_data_without_outliers[col]['min'] for col in selected_columns},
    'semi_intensif_data_without_outliers_max': {col: stats_semi_intensif_data_without_outliers[col]['max'] for col in selected_columns},

    'intensif_data_outliers_min': {col: stats_intensif_data_outliers[col]['min'] for col in selected_columns},
    'intensif_data_outliers_max': {col: stats_intensif_data_outliers[col]['max'] for col in selected_columns},
    'intensif_data_without_outliers_min': {col: stats_intensif_data_without_outliers[col]['min'] for col in selected_columns},
    'intensif_data_without_outliers_max': {col: stats_intensif_data_without_outliers[col]['max'] for col in selected_columns},

    'super_intensif_data_outliers_min': {col: stats_super_intensif_data_outliers[col]['min'] for col in selected_columns},
    'super_intensif_data_outliers_max': {col: stats_super_intensif_data_outliers[col]['max'] for col in selected_columns},
    'super_intensif_data_without_outliers_min': {col: stats_super_intensif_data_without_outliers[col]['min'] for col in selected_columns},
    'super_intensif_data_without_outliers_max': {col: stats_super_intensif_data_without_outliers[col]['max'] for col in selected_columns},

    'semi_intensif_data_without_outliers_mode': {col: stats_semi_intensif_data_without_outliers[col]['mode'] for col in selected_columns},

    'intensif_data_outliers_mode': {col: stats_intensif_data_outliers[col]['mode'] for col in selected_columns},
    'intensif_data_without_outliers_mode': {col: stats_intensif_data_without_outliers[col]['mode'] for col in selected_columns},

    'super_intensif_data_outliers_mode': {col: stats_super_intensif_data_outliers[col]['mode'] for col in selected_columns},
    'super_intensif_data_without_outliers_mode': {col: stats_super_intensif_data_without_outliers[col]['mode'] for col in selected_columns},
})

comparison = pd.DataFrame(comparison)
comparison = comparison.T
comparison
# Out:
#                                                area  padat_tebar  \
# semi_intensif_data_without_outliers_min    30000.00     7.040000
# semi_intensif_data_without_outliers_max    40000.00    10.500000
# intensif_data_outliers_min                  1500.00    16.000320
# intensif_data_outliers_max                  4999.90    50.000000
# intensif_data_without_outliers_min           896.00    19.241341
# intensif_data_without_outliers_max          5142.32    50.000000
# super_intensif_data_outliers_min               7.00    50.001000
# super_intensif_data_outliers_max            4999.90  1851.851852
# super_intensif_data_without_outliers_min       7.00    50.001000
# super_intensif_data_without_outliers_max    8900.00   779.220779
# semi_intensif_data_without_outliers_mode   30000.00     7.040000
# intensif_data_outliers_mode                 1500.00    16.000320
# intensif_data_without_outliers_mode         4999.90    40.000800
# super_intensif_data_outliers_mode            300.00   100.000000
# super_intensif_data_without_outliers_mode   4999.90    60.001200
#
#                                            sum_feed_weight  \
# semi_intensif_data_without_outliers_min           3187.520
# semi_intensif_data_without_outliers_max           6532.440
# intensif_data_outliers_min                         325.000
# intensif_data_outliers_max                        4660.000
# intensif_data_without_outliers_min                  14.600
# intensif_data_without_outliers_max               10619.000
# super_intensif_data_outliers_min                    17.325
# super_intensif_data_outliers_max                 10846.250
# super_intensif_data_without_outliers_min            19.670
# super_intensif_data_without_outliers_max         29497.900
# semi_intensif_data_without_outliers_mode          3187.520
# intensif_data_outliers_mode                        325.000
# intensif_data_without_outliers_mode                 14.600
# super_intensif_data_outliers_mode                   17.325
# super_intensif_data_without_outliers_mode         1555.100
#
#                                            sum_weight_biomassa  sum_biomassa  \
# semi_intensif_data_without_outliers_min                1470.86   107299.2370
# semi_intensif_data_without_outliers_max                2015.90   169537.1900
# intensif_data_outliers_min                               20.00     2500.0000
# intensif_data_outliers_max                             2325.00    86955.0000
# intensif_data_without_outliers_min                       25.00     5900.0000
# intensif_data_without_outliers_max                     5472.00   183018.0000
# super_intensif_data_outliers_min                          0.59       59.0000
# super_intensif_data_outliers_max                      10300.00   427862.5016
# super_intensif_data_without_outliers_min                  4.21      210.5000
# super_intensif_data_without_outliers_max              10369.10   752840.0000
# semi_intensif_data_without_outliers_mode               1470.86   107299.2370
# intensif_data_outliers_mode                              20.00     2500.0000
# intensif_data_without_outliers_mode                      25.00     5900.0000
# super_intensif_data_outliers_mode                        80.00       59.0000
# super_intensif_data_without_outliers_mode               400.00      210.5000
#
#                                            avg_evening_do  \
# semi_intensif_data_without_outliers_min          2.819500
# semi_intensif_data_without_outliers_max          4.659000
# intensif_data_outliers_min                       6.171772
# intensif_data_outliers_max                      10.359385
# intensif_data_without_outliers_min               5.083702
# intensif_data_without_outliers_max               8.580312
# super_intensif_data_outliers_min                 3.840500
# super_intensif_data_outliers_max                22.161522
# super_intensif_data_without_outliers_min         1.329000
# super_intensif_data_without_outliers_max        16.436364
# semi_intensif_data_without_outliers_mode         2.819500
# intensif_data_outliers_mode                      6.171772
# intensif_data_without_outliers_mode              5.083702
# super_intensif_data_outliers_mode                5.923953
# super_intensif_data_without_outliers_mode        5.654959
#
#                                            avg_morning_salinity  \
# semi_intensif_data_without_outliers_min               23.661952
# semi_intensif_data_without_outliers_max               24.478723
# intensif_data_outliers_min                             5.034515
# intensif_data_outliers_max                            24.753846
# intensif_data_without_outliers_min                     5.555814
# intensif_data_without_outliers_max                    34.083333
# super_intensif_data_outliers_min                       8.070007
# super_intensif_data_outliers_max                      36.288889
# super_intensif_data_without_outliers_min               4.138889
# super_intensif_data_without_outliers_max             192.300000
# semi_intensif_data_without_outliers_mode              23.661952
# intensif_data_outliers_mode                            5.034515
# intensif_data_without_outliers_mode                    5.555814
# super_intensif_data_outliers_mode                     17.969135
# super_intensif_data_without_outliers_mode             23.842999
#
#                                            avg_evening_salinity  \
# semi_intensif_data_without_outliers_min               19.460000
# semi_intensif_data_without_outliers_max               19.558000
# intensif_data_outliers_min                             4.634800
# intensif_data_outliers_max                            23.650000
# intensif_data_without_outliers_min                     6.017391
# intensif_data_without_outliers_max                    32.000000
# super_intensif_data_outliers_min                       7.803696
# super_intensif_data_outliers_max                      35.600000
# super_intensif_data_without_outliers_min               4.132075
# super_intensif_data_without_outliers_max              46.244580
# semi_intensif_data_without_outliers_mode              19.460000
# intensif_data_outliers_mode                            4.634800
# intensif_data_without_outliers_mode                    6.017391
# super_intensif_data_outliers_mode                     17.713345
# super_intensif_data_without_outliers_mode             21.277778
#
#                                            avg_transparency  avg_ammonia  \
# semi_intensif_data_without_outliers_min           31.234940     0.035727
# semi_intensif_data_without_outliers_max           41.222222     0.035727
# intensif_data_outliers_min                        40.000000     0.041429
# intensif_data_outliers_max                        47.927350     0.099750
# intensif_data_without_outliers_min                22.611111     0.017667
# intensif_data_without_outliers_max                62.542373     0.200000
# super_intensif_data_outliers_min                  28.333333     0.004500
# super_intensif_data_outliers_max                  54.284177   342.883333
# super_intensif_data_without_outliers_min           1.200000     0.000000
# super_intensif_data_without_outliers_max          70.437500    70.000000
# semi_intensif_data_without_outliers_mode          31.234940     0.035727
# intensif_data_outliers_mode                       40.000000     0.099750
# intensif_data_without_outliers_mode               42.797980     0.035727
# super_intensif_data_outliers_mode                 40.000000     0.099750
# super_intensif_data_without_outliers_mode         42.797980     0.035727
#
#                                            avg_calcium     avg_tom
# semi_intensif_data_without_outliers_min     381.538462   96.142857
# semi_intensif_data_without_outliers_max     397.142857  102.307692
# intensif_data_outliers_min                  537.277778   58.048000
# intensif_data_outliers_max                  740.000000   94.213333
# intensif_data_without_outliers_min          406.666667   65.133333
# intensif_data_without_outliers_max          850.000000   92.642857
# super_intensif_data_outliers_min            219.333333   38.000000
# super_intensif_data_outliers_max           2000.000000   96.666667
# super_intensif_data_without_outliers_min      0.000000    0.000000
# super_intensif_data_without_outliers_max   2000.000000  156.000000
# semi_intensif_data_without_outliers_mode    381.538462   96.142857
# intensif_data_outliers_mode                 537.277778   61.674603
# intensif_data_without_outliers_mode         406.666667   92.642857
# super_intensif_data_outliers_mode           537.277778   61.674603
# super_intensif_data_without_outliers_mode   406.666667   92.642857
